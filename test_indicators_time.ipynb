# %%
from indicators import *
from handle_time import *
from binance import Client
import pandas as pd

# %%
client=Client()

# %%
btc=client.get_historical_klines('BTCUSDT', client.KLINE_INTERVAL_5MINUTE, '25 Nov, 2024')

# %%
btc_df=create_df(btc)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades
# 0         1732493099999     28572
# ...

# %% [markdown]
# # Test indicators

# %%
add_ema(btc_df, 10, 20, 50, 100, 200)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20        ema_50  \
# ...

# %%
rsi(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20        ema_50  \
# ...

# %%
macd(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20        ema_50  \
# ...

# %%
bollinger_bands(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20        ema_50  \
# ...

# %%
stochastic_oscillator(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20        ema_50  \
# ...

# %%
atr(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20  ...  \
# ...

# %%
chaikin_money_flow(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20  ...  \
# ...

# %% [markdown]
# # Test time handling functions

# %%
is_weekend(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20  ...        rsi  \
# ...

# %%
len(btc_df[btc_df['is_weekend']==True]), len(btc_df[btc_df['is_weekend']==False])
# Out:
# (29952, 75598)

# %%
cyclical_days(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20  ...  \
# ...

# %%
cyclical_hours(btc_df)
btc_df
# Out:
#         open_timestamp      open      high       low     close     volume  \
# 0        1732492800000  97900.05  97968.58  97654.11  97739.99  147.80644
# 1        1732493100000  97740.00  97940.21  97740.00  97816.34  125.55420
# 2        1732493400000  97816.34  97913.49  97694.49  97694.50   68.87987
# 3        1732493700000  97694.50  97913.49  97694.49  97907.97   65.55586
# 4        1732494000000  97907.98  97907.98  97713.95  97740.01   56.57029
# ...                ...       ...       ...       ...       ...        ...
# 105545   1764156300000  86884.16  86951.80  86864.66  86896.44   39.95081
# 105546   1764156600000  86896.44  86948.12  86872.00  86907.22   28.85160
# 105547   1764156900000  86907.21  86969.53  86884.86  86910.29   27.69264
# 105548   1764157200000  86910.29  87058.52  86894.08  87053.72   48.52627
# 105549   1764157500000  87053.72  87094.37  86956.99  86956.99   35.84226
#
#         close_timestamp  n_trades        ema_10        ema_20  ...  \
# ...

# %%
btc_df.dropna(inplace=True)

# %%
btc_df.reset_index(inplace=True)

# %%
btc_df.drop(columns=['open_timestamp', 'close_timestamp'], inplace=True)

# %%
btc_df.drop(columns=['index'], inplace=True)

# %%
btc_df
# Out:
#             open      high       low     close     volume  n_trades  \
# 0       96159.90  96190.44  95954.35  95975.99  151.98309     34615
# 1       95975.99  96048.76  95833.33  95863.99  176.22417     41649
# 2       95863.99  96020.00  95756.00  95760.02  153.25939     30902
# 3       95760.03  96129.86  95711.20  95878.99  185.01925     27349
# 4       95879.00  96060.00  95878.99  95912.00   78.83363     21991
# ...          ...       ...       ...       ...        ...       ...
# 105346  86884.16  86951.80  86864.66  86896.44   39.95081      9201
# 105347  86896.44  86948.12  86872.00  86907.22   28.85160      9353
# 105348  86907.21  86969.53  86884.86  86910.29   27.69264      8779
# 105349  86910.29  87058.52  86894.08  87053.72   48.52627      9647
# 105350  87053.72  87094.37  86956.99  86956.99   35.84226      8060
#
#               ema_10        ema_20        ema_50       ema_100  ...  \
# 0       96084.323711  96154.612830  96659.422202  97155.235063  ...
# ...

# %%
btc_df['percent_change']=btc_df['close'].pct_change()*100
btc_df
# Out:
#             open      high       low     close     volume  n_trades  \
# 0       95975.99  96048.76  95833.33  95863.99  176.22417     41649
# 1       95863.99  96020.00  95756.00  95760.02  153.25939     30902
# 2       95760.03  96129.86  95711.20  95878.99  185.01925     27349
# 3       95879.00  96060.00  95878.99  95912.00   78.83363     21991
# 4       95912.00  95912.00  95548.00  95593.56  223.98587     43609
# ...          ...       ...       ...       ...        ...       ...
# 105345  86884.16  86951.80  86864.66  86896.44   39.95081      9201
# 105346  86896.44  86948.12  86872.00  86907.22   28.85160      9353
# 105347  86907.21  86969.53  86884.86  86910.29   27.69264      8779
# 105348  86910.29  87058.52  86894.08  87053.72   48.52627      9647
# 105349  87053.72  87094.37  86956.99  86956.99   35.84226      8060
#
#               ema_10        ema_20        ema_50       ema_100  ...  \
# 0       96044.263036  96126.934465  96628.218736  97129.198482  ...
# ...

# %%
btc_df.dropna(inplace=True)

# %%
btc_df.reset_index(inplace=True)
btc_df.drop(columns=['index'], inplace=True)

# %%
btc_df.dtypes
# Out:
# open              float64
# high              float64
# low               float64
# close             float64
# volume            float64
# n_trades            int64
# ema_10            float64
# ema_20            float64
# ema_50            float64
# ema_100           float64
# ema_200           float64
# rsi               float64
# macd_line         float64
# signal_line       float64
# upper_band        float64
# lower_band        float64
# k                 float64
# d                 float64
# atr               float64
# cmf               float64
# is_weekend           bool
# sin_days          float64
# cos_days          float64
# sin_hours         float64
# cos_hours         float64
# percent_change    float64
# dtype: object

# %%
btc_df
# Out:
#             open      high       low     close     volume  n_trades  \
# 0       95863.99  96020.00  95756.00  95760.02  153.25939     30902
# 1       95760.03  96129.86  95711.20  95878.99  185.01925     27349
# 2       95879.00  96060.00  95878.99  95912.00   78.83363     21991
# 3       95912.00  95912.00  95548.00  95593.56  223.98587     43609
# 4       95593.56  95645.94  95404.50  95457.67  174.76824     42023
# ...          ...       ...       ...       ...        ...       ...
# 105344  86884.16  86951.80  86864.66  86896.44   39.95081      9201
# 105345  86896.44  86948.12  86872.00  86907.22   28.85160      9353
# 105346  86907.21  86969.53  86884.86  86910.29   27.69264      8779
# 105347  86910.29  87058.52  86894.08  87053.72   48.52627      9647
# 105348  87053.72  87094.37  86956.99  86956.99   35.84226      8060
#
#               ema_10        ema_20        ema_50       ema_100  ...  \
# 0       95992.582484  96091.990230  96594.161192  97101.600447  ...
# ...
